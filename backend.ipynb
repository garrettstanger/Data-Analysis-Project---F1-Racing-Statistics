# %%
import pandas as pd
# My dataset has several different csv files so I have been reading the files seperate each time I open
# a new one.
df = pd.read_csv("drivers.csv", usecols=["driverRef"])
df.head(10)
# Out:
#     driverRef
# 0    hamilton
# 1    heidfeld
# 2     rosberg
# 3      alonso
# 4  kovalainen
# 5    nakajima
# 6    bourdais
# 7   raikkonen
# 8      kubica
# 9       glock

# %%
import pandas as pd
df = pd.read_csv("lap_times.csv")
# Example of sorting values
df.sort_values("time", ascending=True).head(30)
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 488409    1046       847   80        14  0:55.404         55404
# 488412    1046       847   83        12  0:56.319         56319
# 488404    1046       847   75         2  0:56.393         56393
# 488405    1046       847   76         2  0:56.442         56442
# 488413    1046       847   84        11  0:56.499         56499
# 488402    1046       847   73         2  0:56.514         56514
# 488410    1046       847   81        13  0:56.542         56542
# 488401    1046       847   72         3  0:56.563         56563
# 488476    1046       822   60         2  0:56.563         56563
# 488475    1046       822   59         2  0:56.613         56613
# 488376    1046       847   47         2  0:56.644         56644
# 488470    1046       822   54         2  0:56.676         56676
# 488469    1046       822   53         2  0:56.704         56704
# 488467    1046       822   51         2  0:56.705         56705
# ...

# %% [markdown]
# Which driver has the most wins overall?

# %%
import pandas as pd
df = pd.read_csv("results.csv")
# Lots of different kinds of graphs, bar graph was best for this dataset.
df["driverId"].value_counts().head(10).plot.bar(x="driverId")
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("drivers.csv")
KenMiles = df[df["driverId"] == 495]
KenMiles.head()
# Out:
#      driverId  driverRef number code forename surname         dob nationality  \
# 495       495  ken_miles     \N   \N      Ken   Miles  1918-11-01     British
#
#                                         url
# 495  http://en.wikipedia.org/wiki/Ken_Miles

# %% [markdown]
# What are Lewis Hamilton's best times?

# %%
df = pd.read_csv("lap_times.csv")
hamilton = df[df["driverId"] == 1]
hamilton.sort_values("milliseconds", ascending=True).head(30)
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 473711    1032         1   68         1  1:06.719         66719
# 473709    1032         1   66         1  1:07.018         67018
# 499095    1058         1   71         2  1:07.058         67058
# 435206     997         1   58         4  1:07.241         67241
# 414895     977         1   69         4  1:07.411         67411
# 414891     977         1   65         4  1:07.424         67424
# 435204     997         1   56         4  1:07.460         67460
# 414894     977         1   68         4  1:07.503         67503
# 414887     977         1   61         4  1:07.511         67511
# 414893     977         1   67         4  1:07.543         67543
# 435202     997         1   54         4  1:07.571         67571
# 414885     977         1   59         4  1:07.571         67571
# 435207     997         1   59         4  1:07.591         67591
# 414884     977         1   58         4  1:07.608         67608
# ...

# %%
import pandas as pd
df = pd.read_csv("lap_times.csv")
df.head(10)
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342
# 5     841        20    6         1  1:32.605         92605
# 6     841        20    7         1  1:32.502         92502
# 7     841        20    8         1  1:32.537         92537
# 8     841        20    9         1  1:33.240         93240
# 9     841        20   10         1  1:32.572         92572

# %%
import pandas as pd
df = pd.read_csv("lap_times.csv")
# How to change data types
# I changed an int64 to a float. Not very practical for my data but just wanted to practice.
display(df.dtypes)
df["milliseconds"] = df["milliseconds"].astype(float)
display(df["milliseconds"])
# Out:
# raceId           int64
# driverId         int64
# lap              int64
# position         int64
# time            object
# milliseconds     int64
# dtype: object
# 0         98109.0
# 1         93006.0
# 2         92713.0
# 3         92803.0
# 4         92342.0
#            ...
# 517568    82589.0
# 517569    82758.0
# 517570    82658.0
# 517571    98438.0
# 517572    87465.0
# Name: milliseconds, Length: 517573, dtype: float64
